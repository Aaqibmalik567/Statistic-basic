# %% [markdown]
# **Q1. What is statistics, and why is it important?**
# A: Statistics is the science of collecting, organizing, analyzing, and interpreting data. It helps make decisions and predictions based on data.
#
# ---
#
# **Q2. What are the two main types of statistics?**
# A:
#
# 1. Descriptive Statistics
# 2. Inferential Statistics
#
# ---
#
# **Q3. What are descriptive statistics?**
# A: These summarize and describe the features of a dataset using tools like mean, median, mode, range, and standard deviation.
#
# ---
#
# **Q4. What is inferential statistics?**
# A: It uses a sample of data to make predictions or inferences about a population.
#
# ---
#
# **Q5. What is sampling in statistics?**
# A: Sampling is the process of selecting a subset of individuals from a population to estimate the characteristics of the whole group.
#
# ---
#
# **Q6. What are the different types of sampling methods?**
# A:
#
# * Random Sampling
# * Stratified Sampling
# * Systematic Sampling
# * Cluster Sampling
# * Convenience Sampling
#
# ---
#
# **Q7. What is the difference between random and non-random sampling?**
# A: Random sampling gives every item an equal chance of selection, while non-random sampling involves personal judgment or convenience.
#
# ---
#
# **Q8. Define and give examples of qualitative and quantitative data.**
# A:
#
# * Qualitative (Categorical): Gender, color, city
# * Quantitative (Numerical): Height, age, income
#
# ---
#
# **Q9. What are the different types of data in statistics?**
# A:
#
# * Nominal
# * Ordinal
# * Interval
# * Ratio
#
# ---
#
# **Q10. Explain nominal, ordinal, interval, and ratio levels of measurement.**
# A:
#
# * Nominal: Categories without order (e.g., gender)
# * Ordinal: Ordered categories (e.g., rankings)
# * Interval: Ordered, with equal spacing, no true zero (e.g., temperature)
# * Ratio: Like interval, but has a true zero (e.g., weight, income)
#
# ---
#
# **Q11. What is the measure of central tendency?**
# A: It is a single value that represents the center or average of a dataset. (Mean, Median, Mode)
#
# ---
#
# **Q12. Define mean, median, and mode.**
# A:
#
# * Mean: Arithmetic average
# * Median: Middle value when sorted
# * Mode: Most frequently occurring value
#
# ---
#
# **Q13. What is the significance of the measure of central tendency?**
# A: It helps summarize a large dataset with a single representative value.
#
# ---
#
# **Q14. What is variance, and how is it calculated?**
# A: Variance is the average of the squared differences from the mean. It shows how data is spread out.
#
# ---
#
# **Q15. What is standard deviation, and why is it important?**
# A: Standard deviation is the square root of variance. It is widely used to measure data spread in the same unit as the data.
#
# ---
#
# **Q16. Define and explain the term range in statistics.**
# A: Range is the difference between the highest and lowest values in a dataset.
#
# ---
#
# **Q17. What is the difference between variance and standard deviation?**
# A: Variance is in squared units; standard deviation is its square root, making it easier to interpret.
#
# ---
#
# **Q18. What is skewness in a dataset?**
# A: Skewness describes the asymmetry of a data distribution.
#
# ---
#
# **Q19. What does it mean if a dataset is positively or negatively skewed?**
# A:
#
# * Positive skew: Right tail is longer
# * Negative skew: Left tail is longer
#
# ---
#
# **Q20. Define and explain kurtosis.**
# A: Kurtosis measures the “tailedness” or peakedness of a distribution compared to a normal distribution.
#
# ---
#
# **Q21. What is the purpose of covariance?**
# A: Covariance measures how two variables change together (positive or negative relationship).
#
# ---
#
# **Q22. What does correlation measure in statistics?**
# A: Correlation measures the strength and direction of the linear relationship between two variables.
#
# ---
#
# **Q23. What is the difference between covariance and correlation?**
# A: Correlation is standardized (−1 to +1), while covariance is not and depends on the units of measurement.
#
# ---
#
# **Q24. What are some real-world applications of statistics?**
# A:
#
# * Healthcare (disease prediction)
# * Business (market analysis)
# * Sports (performance analysis)
# * Government (population studies)
# * Finance (stock market forecasting)

# %%
# 📌 Q1: How do you calculate the mean, median, and mode of a dataset?

import numpy as np
import pandas as pd

# Sample dataset
data = np.array([12, 15, 14, 10, 8, 12, 14, 16, 18, 20])

# Calculating Mean
mean = np.mean(data)

# Calculating Median
median = np.median(data)

# Calculating Mode using pandas
mode = pd.Series(data).mode().iloc[0]

print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
# Out:
# Mean: 13.9
# Median: 14.0
# Mode: 12

# %%
# 📌 Q2: Write a Python program to compute the variance and standard deviation of a dataset

import numpy as np

data = np.array([12, 15, 14, 10, 8, 12, 14, 16, 18, 20])

# Variance
variance = np.var(data)

# Standard Deviation
std_dev = np.std(data)

print("Variance:", variance)
print("Standard Deviation:", std_dev)
# Out:
# Variance: 11.690000000000001
# Standard Deviation: 3.419064199455752

# %%
# 📌 Q3: Write a Python function to calculate the range of a dataset

def calc_range(dataset):
    return np.max(dataset) - np.min(dataset)

print("Range:", calc_range(data))
# Out:
# Range: 12

# %%
# 📌 Q4: Create a dataset and classify it into nominal, ordinal, interval, and ratio types

import pandas as pd

levels_example = {
    'Nominal': ['Red', 'Blue', 'Green'],
    'Ordinal': ['Low', 'Medium', 'High'],
    'Interval': [10, 20, 30],
    'Ratio': [5, 10, 15]
}

df_levels = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in levels_example.items()]))
print(df_levels)
# Out:
#   Nominal Ordinal  Interval  Ratio
# 0     Red     Low        10      5
# 1    Blue  Medium        20     10
# 2   Green    High        30     15

# %%
# 📌 Q5: Create a dataset and plot its histogram to visualize skewness

import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis

# Sample dataset (same as before)
sns.histplot(data, kde=True)
plt.title("Histogram with KDE - Skewness")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

print("Skewness:", skew(data))
print("Kurtosis:", kurtosis(data))
# Out:
# Skewness: 0.07025469241454795
# Kurtosis: -0.6896625909856944

# %%
# 📌 Q6: Generate a dataset and demonstrate positive and negative skewness

positive_skew = np.random.exponential(size=1000)
negative_skew = -np.random.exponential(size=1000)

plt.figure(figsize=(12,5))

# Positive Skew
plt.subplot(1, 2, 1)
sns.histplot(positive_skew, kde=True, color='blue')
plt.title("Positive Skew")

# Negative Skew
plt.subplot(1, 2, 2)
sns.histplot(negative_skew, kde=True, color='red')
plt.title("Negative Skew")

plt.tight_layout()
plt.show()

# %%
# 📌 Q7: Write a Python script to calculate covariance between two datasets

x = np.random.randint(10, 100, 50)
y = x + np.random.randint(-10, 10, 50)

cov_matrix = np.cov(x, y)
print("Covariance between x and y:", cov_matrix[0, 1])
# Out:
# Covariance between x and y: 759.0408163265304

# %%
# 📌 Q8: Write a Python script to calculate the correlation coefficient between two datasets

corr_matrix = np.corrcoef(x, y)
print("Correlation Coefficient between x and y:", corr_matrix[0, 1])
# Out:
# Correlation Coefficient between x and y: 0.9759359032320785

# %%
# 📌 Q9: Create a scatter plot to visualize the relationship between two variables

plt.scatter(x, y, color='green')
plt.title("Scatter Plot: X vs Y")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.grid(True)
plt.show()

# %%
# 📌 Q10: Implement and compare simple random sampling and stratified sampling

import pandas as pd

df = pd.DataFrame({
    'gender': ['M', 'F', 'M', 'F', 'F', 'M', 'M', 'F', 'M', 'F'],
    'score': [88, 92, 75, 65, 78, 90, 85, 70, 95, 60]
})

# Simple Random Sampling
random_sample = df.sample(n=4)

# Stratified Sampling (2 samples per gender)
stratified_sample = df.groupby('gender', group_keys=False).apply(lambda x: x.sample(2))

print("Random Sample:\n", random_sample)
print("\nStratified Sample:\n", stratified_sample)
# Out:
# Random Sample:
#    gender  score
# 9      F     60
# 8      M     95
# 3      F     65
# 4      F     78
#
# Stratified Sample:
#    gender  score
# 1      F     92
# 9      F     60
# 5      M     90
# 2      M     75
# /tmp/ipython-input-18-2093286472.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   stratified_sample = df.groupby('gender', group_keys=False).apply(lambda x: x.sample(2))

# %%
# 📌 Q11: Calculate the mean, median, and mode of grouped data

grouped_data = pd.DataFrame({
    'Class Interval': ['0-10', '10-20', '20-30'],
    'Frequency': [5, 8, 7]
})

grouped_data['Midpoint'] = [5, 15, 25]

# Mean for grouped data
mean_grouped = np.average(grouped_data['Midpoint'], weights=grouped_data['Frequency'])

print("Grouped Data Mean:", mean_grouped)
# Out:
# Grouped Data Mean: 16.0

# %%
# 📌 Q12: Simulate data using Python and calculate its central tendency and dispersion

sim_data = np.random.randint(50, 100, size=20)

print("Simulated Data:", sim_data)
print("Mean:", np.mean(sim_data))
print("Median:", np.median(sim_data))
print("Mode:", pd.Series(sim_data).mode().iloc[0])
print("Standard Deviation:", np.std(sim_data))
print("Variance:", np.var(sim_data))
# Out:
# Simulated Data: [91 93 66 79 64 53 85 54 61 68 83 97 99 84 65 65 99 96 66 66]
# Mean: 76.7
# Median: 73.5
# Mode: 66
# Standard Deviation: 15.156186855538564
# Variance: 229.70999999999998

# %%
# 📌 Q13: Use NumPy or pandas to summarize a dataset’s descriptive statistics

df_stats = pd.DataFrame({'Score': sim_data})
print(df_stats.describe())
# Out:
#           Score
# count  20.00000
# mean   76.70000
# std    15.54992
# min    53.00000
# 25%    65.00000
# 50%    73.50000
# 75%    91.50000
# max    99.00000

# %%
# 📌 Q14: Plot a boxplot to understand the spread and identify outliers

sns.boxplot(x=data)
plt.title("Boxplot of Dataset")
plt.xlabel("Values")
plt.grid(True)
plt.show()

# %%
# 📌 Q15: Calculate the interquartile range (IQR) of a dataset

Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1

print("Interquartile Range (IQR):", IQR)
# Out:
# Interquartile Range (IQR): 3.75

# %%
# 📌 Q16: Implement Z-score normalization and explain its significance

z_scores = (data - np.mean(data)) / np.std(data)
print("Z-scores:", z_scores)

# Z-score normalization centers data around 0 with unit standard deviation.
# Out:
# Z-scores: [-0.55570761  0.32172546  0.02924777 -1.14066299 -1.72561837 -0.55570761
#   0.02924777  0.61420315  1.19915853  1.78411391]

# %%
# 📌 Q17: Compare two datasets using their standard deviations

data1 = np.random.randint(10, 100, size=10)
data2 = np.random.randint(30, 80, size=10)

std1 = np.std(data1)
std2 = np.std(data2)

print("Dataset 1:", data1)
print("Standard Deviation 1:", std1)

print("Dataset 2:", data2)
print("Standard Deviation 2:", std2)

# The dataset with higher SD is more spread out.
# Out:
# Dataset 1: [57 40 78 58 77 30 49 52 43 36]
# Standard Deviation 1: 15.28397853963424
# Dataset 2: [61 65 66 65 37 59 38 34 51 53]
# Standard Deviation 2: 11.844407963254222

# %%
# 📌 Q18: Write a Python program to visualize covariance using a heatmap

df_cov = pd.DataFrame({'x': x, 'y': y})
cov_matrix = df_cov.cov()

sns.heatmap(cov_matrix, annot=True, cmap='coolwarm')
plt.title("Covariance Heatmap")
plt.show()

# %%
# 📌 Q19: Use seaborn to create a correlation matrix for a dataset

corr_matrix = df_cov.corr()

sns.heatmap(corr_matrix, annot=True, cmap='viridis')
plt.title("Correlation Matrix")
plt.show()

# %%
# 📌 Q20: Implement the Pearson and Spearman correlation coefficients for a dataset

from scipy.stats import pearsonr, spearmanr

pearson_corr, _ = pearsonr(x, y)
spearman_corr, _ = spearmanr(x, y)

print("Pearson Correlation Coefficient:", pearson_corr)
print("Spearman Correlation Coefficient:", spearman_corr)
# Out:
# Pearson Correlation Coefficient: 0.9759359032320787
# Spearman Correlation Coefficient: 0.9680434553896414

# %%
# 📌 Q21: Generate a dataset and implement both variance and standard deviation computations

data_generated = np.random.randint(1, 50, size=15)

variance = np.var(data_generated)
std_dev = np.std(data_generated)

print("Generated Data:", data_generated)
print("Variance:", variance)
print("Standard Deviation:", std_dev)
# Out:
# Generated Data: [ 4  4 19 18 17 46 23 33 32 29  3 45 17 11 49]
# Variance: 218.88888888888889
# Standard Deviation: 14.794894014114764

# %%
# 📌 Q22: Visualize skewness and kurtosis using Python libraries like matplotlib or seaborn

sns.histplot(data_generated, kde=True, color='purple')
plt.title("Distribution with Skewness and Kurtosis")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

print("Skewness:", skew(data_generated))
print("Kurtosis:", kurtosis(data_generated))
# Out:
# Skewness: 0.3084843478740916
# Kurtosis: -1.0358412739313048

# %%
# 📌 Q23: Implement the Pearson correlation coefficient for a dataset

x_vals = np.random.randint(1, 100, size=50)
y_vals = x_vals + np.random.randint(-20, 20, size=50)

pearson_corr, _ = pearsonr(x_vals, y_vals)

print("Pearson Correlation Coefficient:", pearson_corr)
# Out:
# Pearson Correlation Coefficient: 0.9077774644891856

# %%
# 📌 Q24: Implement the Spearman correlation coefficient for a dataset

spearman_corr, _ = spearmanr(x_vals, y_vals)

print("Spearman Correlation Coefficient:", spearman_corr)
# Out:
# Spearman Correlation Coefficient: 0.9116721729310616
